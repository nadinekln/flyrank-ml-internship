# %% [markdown]
# <a href="https://colab.research.google.com/github/nadinekln/flyrank-ml-internship/blob/main/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nadinekln/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I chose the content refresh lane. This is primarily a ranking problem. The goal is not simply to classify pages, but to rank them so that the pages most likely to deserve a content review appear first. A ranking allows a content or SEO team to prioritize limited review time on the pages that may provide the greatest benefit.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target is whether a page is declining. In the starter dataset, I use the provided proxy label based on trend_direction, where pages with trend_direction equal to "down" are treated as declining. This is a practical proxy for identifying pages that may deserve further human review.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df["is_declining"] = (df["trend_direction"] == "down").astype(int)

df[["trend_direction", "is_declining"]].head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_684/549654866.py in <cell line: 0>()
#       2
#       3
# ----> 4 df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")
#       5
#       6 df["is_declining"] = (df["trend_direction"] == "down").astype(int)
#
# ...

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# A useful ranking should place genuinely declining pages near the top of the review queue. Therefore, Precision@50 is an appropriate success metric because it measures how many of the top 50 recommended pages are actually declining. A higher Precision@50 means the review team spends more time on relevant pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# The unit of analysis is one content page. Each row in the dataset represents one page with its measurable search performance, content characteristics, and engagement signals.

# %%
print(f"Dataset shape: {df.shape}")

df[[
    "content_id",
    "client_id",
    "content_type",
    "search_volume",
    "impressions_90d",
    "ctr",
    "avg_position",
    "trend_direction"
]].head()

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule is simple and transparent, but it can only combine a small number of conditions. Machine learning can learn interactions between multiple signals such as impressions, content age, CTR, and average position. In my experiment, the depth-3 decision tree achieved a Precision@50 of 0.720, compared with 0.680 for my hand-written rule, showing that a learned model can produce a better ranking while still remaining interpretable.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
