# %% [markdown]
# <a href="https://colab.research.google.com/github/nadinekln/flyrank-ml-internship/blob/main/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nadinekln/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# One row represents one content page for one monthly observation in the content refresh dataset.
#
# I use a mid-panel month (March 2026) to avoid using the final outcome month. The goal is to analyze measurable page signals available before making a content refresh decision and rank pages that may deserve human review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Features:
# - impressions_90d
# - ctr
# - avg_position
# - content_age_days
# - days_since_last_update
#
# Label / Proxy:
# - trend_direction (down = declining)
#
# Context:
# - client_id
# - month
# - content_id
#
# Excluded:
# - trend_pct
#
# Reason:
# trend_pct is derived from the outcome and would leak future information into the model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# Verification:
#
# • One row corresponds to one content page.
#
# • The dataset contains 30,000 observations.
#
# • The selected features contain very few or no missing values and can be used for modeling after standard preprocessing.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print()

print("Unique content pages:", df["content_id"].nunique())
print("Unique clients:", df["client_id"].nunique())
print()

print("Missing values:")
print(df[[
    "impressions_90d",
    "ctr",
    "avg_position",
    "content_age_days",
    "days_since_last_update"
]].isna().sum())

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# This dataset can identify observed patterns and support content refresh decisions, but it cannot establish causal relationships. It does not explain why a page declined or predict Google's ranking algorithm. The results should be interpreted as decision-support rather than proof of future performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
